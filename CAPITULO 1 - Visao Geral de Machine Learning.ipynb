# %% [markdown]
# # CAPÍTULO 1 - Visão Geral de Machine Learning

# %% [markdown]
# ## 1.3 Tipos de tarefas de Machine Learning

# %%
print('Figura 1.1 — Dados estruturados e não estruturados.')
from IPython.display import Image
Image(filename = "Imagens/dados.png", width = 600)
# Out:
# Figura 1.1 — Dados estruturados e não estruturados.

# %%
print('Figura 1.2 — Tarefas comuns de Machine Learning (resumo simplificado).')
from IPython.display import Image
Image(filename = "Imagens/tarefas.png", width = 600)
# Out:
# Figura 1.2 — Tarefas comuns de Machine Learning (resumo simplificado).

# %% [markdown]
# ## 1.4 Aprendizado supervisionado, não supervisionado e por reforço.

# %%
print('Figura 1.3 — Exemplo de classificação.')
from IPython.display import Image
Image(filename = "Imagens/classificacao.jpg", width = 600)
# Out:
# Figura 1.3 — Exemplo de classificação.

# %%
print('Figura 1.4 — Exemplo de agrupamento.')
from IPython.display import Image
Image(filename = "Imagens/agrupamento.jpg", width = 600)
# Out:
# Figura 1.4 — Exemplo de agrupamento.

# %%
print('Figura 1.5 — Visão geral do Reinforcement Learning.')
from IPython.display import Image
Image(filename = "Imagens/rl.jpg", width = 600)
# Out:
# Figura 1.5 — Visão geral do Reinforcement Learning.

# %%
print('Figura 1.6 — Hierarquia de Inteligência Artificial.')
from IPython.display import Image
Image(filename = "Imagens/ia.jpg", width = 300)
# Out:
# Figura 1.6 — Hierarquia de Inteligência Artificial.

# %%
print('Figura 1.7 — Fluxo de um típico programa de computador.')
from IPython.display import Image
Image(filename = "Imagens/tradicional.jpg", width = 600)
# Out:
# Figura 1.7 — Fluxo de um típico programa de computador.

# %%
print('Figura 1.8. — Programação tradicional: entram dados e regras, saem respostas.')
from IPython.display import Image
Image(filename = "Imagens/resp.jpg", width = 300)
# Out:
# Figura 1.8. — Programação tradicional: entram dados e regras, saem respostas.

# %%
print('Figura 1.9 — Programação Machine Learning: entram dados e respostas, saem regras.')
from IPython.display import Image
Image(filename = "Imagens/regras.jpg",width = 300)
# Out:
# Figura 1.9 — Programação Machine Learning: entram dados e respostas, saem regras.

# %%
print('Figura 1.10 — Modelo de processo customizado para Machine Learning.')
from IPython.display import Image
Image(filename = "Imagens/ml.jpg",width = 950)
# Out:
# Figura 1.10 — Modelo de processo customizado para Machine Learning.

# %%
print('Figura 1.11 — Profissionais de Data Science.')
from IPython.display import Image
Image(filename = "Imagens/conhecimento.jpeg",width = 600)
# Out:
# Figura 1.11 — Profissionais de Data Science.
