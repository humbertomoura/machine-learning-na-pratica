# %% [markdown]
# ## CAPÍTULO 2 - Software Necessário

# %% [markdown]
# ## 2.1	Instalação do Python e Bibliotecas Recomendadas

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib as plt

print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
print(plt.__version__)
print('Hello World!')
# Out:
# 1.21.5
# 1.4.2
# 1.0.2
# 3.5.1
# Hello World!

# %%
print('Figura 2.1 — Programa teste.py..')
from IPython.display import Image
Image(filename = "Imagens/prompt.jpg", width = 500)
# Out:
# Figura 2.1 — Programa teste.py..

# %% [markdown]
# ## 2.2	Instalação do Anaconda

# %%
print('Figura 2.2 — Interface Anaconda Navigator.')
from IPython.display import Image
Image(filename = "Imagens/anaconda.jpg", width = 600)
# Out:
# Figura 2.2 — Interface Anaconda Navigator.

# %%
print('Figura 2.3 — Interface Inicial Jupyter Notebook.')
from IPython.display import Image
Image(filename = "Imagens/jupyter.jpg", width = 600)
# Out:
# Figura 2.3 — Interface Inicial Jupyter Notebook.

# %%
print('Figura 2.4 — Interface Novo arquivo Python.')
from IPython.display import Image
Image(filename = "Imagens/jupyter-novo-arquivo.jpg", width = 600)
# Out:
# Figura 2.4 — Interface Novo arquivo Python.

# %%
print('Figura 2.5 — Execução do código Python.')
from IPython.display import Image
Image(filename = "Imagens/novo-comando.jpg", width = 600)
# Out:
# Figura 2.5 — Execução do código Python.

# %%
print('Figura 2.6 — Execução do código Python com 3 linhas de código.')
from IPython.display import Image
Image(filename = "Imagens/jupyter-exec.jpg", width = 600)
# Out:
# Figura 2.6 — Execução do código Python com 3 linhas de código.

# %% [markdown]
# ## 2.3	Utilização do Google Colab

# %%
print('Figura 2.7 —Execução do código Google Colab.')
from IPython.display import Image
Image(filename = "Imagens/colab.jpg", width = 600)
# Out:
# Figura 2.7 —Execução do código Google Colab.

# %% [markdown]
# ## 2.4	IDE Microsoft VS Code

# %%
print('Figura 2.11 — Site do Microsoft VS Code.')
from IPython.display import Image
Image(filename = "Imagens/vscode.jpg", width = 600)
# Out:
# Figura 2.11 — Site do Microsoft VS Code.

# %%
print('Figura 2.12 — Seleção de versão do Python.')
from IPython.display import Image
Image(filename = "Imagens/versao-python.jpg", width = 300)
# Out:
# Figura 2.12 — Seleção de versão do Python.

# %%
print('Figura 2.14 — Saída do Programa Python.')
from IPython.display import Image
Image(filename = "Imagens/debug.jpg", width = 600)
# Out:
# Figura 2.14 — Saída do Programa Python.
